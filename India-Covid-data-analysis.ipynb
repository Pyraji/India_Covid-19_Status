# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline
import seaborn as sns
#importing plotly Library
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls

# %%
df = pd.read_csv(r"C:\Users\jagad\gamaka\ML\projects\personal_project\Latest Covid-19 India Status.csv")

# %%
df.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  \
# 0  Andaman and Nicobar         7525      14        7382     129
# 1       Andhra Pradesh      1952513   22358     1916914   13241
# 2    Arunachal Pradesh        45703    4465       41025     213
# 3                Assam       557437   15726      536597    5114
# 4                Bihar       724390     530      714223    9637
#
#    Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# 0              0.19                98.10             1.71
# 1              1.15                98.18             0.68
# 2              9.77                89.76             0.47
# 3              2.82                96.26             0.92
# 4              0.07                98.60             1.33

# %%
# df.info()
df.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  \
# 0  Andaman and Nicobar         7525      14        7382     129
# 1       Andhra Pradesh      1952513   22358     1916914   13241
# 2    Arunachal Pradesh        45703    4465       41025     213
# 3                Assam       557437   15726      536597    5114
# 4                Bihar       724390     530      714223    9637
#
#    Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# 0              0.19                98.10             1.71
# 1              1.15                98.18             0.68
# 2              9.77                89.76             0.47
# 3              2.82                96.26             0.92
# 4              0.07                98.60             1.33

# %% [markdown]
# # No null data

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
#Reading Column Names
df.columns
# Out:
# Index(['State/UTs', 'Total Cases', 'Active', 'Discharged', 'Deaths',
#        'Active Ratio (%)', 'Discharge Ratio (%)', 'Death Ratio (%)'],
#       dtype='object')

# %%
df.shape
# Out:
# (36, 8)

# %% [markdown]
# # State wise update

# %%
df.plot.bar( title="State wise update",x="State/UTs",orientation="horizontal",figsize=(30,5))
# Out:
# <AxesSubplot:title={'center':'State wise update'}, xlabel='State/UTs'>

# %% [markdown]
# # 1. Active cases out of total cases in state

# %%
sns.relplot(x="Total Cases",y="State/UTs",hue="Active",data=df)

# %%
#df.plot.hexbin(x="Total Cases",y="Active",gridsize=20)
#df
#df.plot.bar( title="Total death",x="Deaths",orientation="horizontal",figsize=(30,5))

# %% [markdown]
# # 2 . Nation wide impact at one glance

# %%
df.plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
df.plot(subplots=True,layout=(4,5),figsize=(15,10))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df_plot=pd.DataFrame(df,columns=[ "State/UTs","Total Cases"])

# %%
df_plot
# Out:
#                                    State/UTs  Total Cases
# 0                        Andaman and Nicobar         7525
# 1                             Andhra Pradesh      1952513
# 2                          Arunachal Pradesh        45703
# 3                                      Assam       557437
# 4                                      Bihar       724390
# 5                                 Chandigarh        61922
# 6                               Chhattisgarh      1001037
# 7   Dadra and Nagar Haveli and Daman and Diu        10637
# 8                                      Delhi      1435844
# 9                                        Goa       170416
# 10                                   Gujarat       824683
# 11                                   Haryana       769717
# 12                          Himachal Pradesh       205017
# 13                         Jammu and Kashmir       320491
# 14                                 Jharkhand       346918
# ...

# %% [markdown]
# # 3. State wise total cases

# %%
df_plot.plot.bar( title="State wise update",x="State/UTs",figsize=(10,10))
# Out:
# <AxesSubplot:title={'center':'State wise update'}, xlabel='State/UTs'>

# %%
#df1=pd.DataFrame(df,columns=[ "State/UTs","Total Cases", "Active", "Discharged", "Deaths"])
df1=pd.DataFrame(df,columns=[ "State/UTs","Total Cases", "Deaths"])

# %%
df1
# Out:
#                                    State/UTs  Total Cases  Deaths
# 0                        Andaman and Nicobar         7525     129
# 1                             Andhra Pradesh      1952513   13241
# 2                          Arunachal Pradesh        45703     213
# 3                                      Assam       557437    5114
# 4                                      Bihar       724390    9637
# 5                                 Chandigarh        61922     809
# 6                               Chhattisgarh      1001037   13511
# 7   Dadra and Nagar Haveli and Daman and Diu        10637       4
# 8                                      Delhi      1435844   25041
# 9                                        Goa       170416    3126
# 10                                   Gujarat       824683   10076
# 11                                   Haryana       769717    9617
# 12                          Himachal Pradesh       205017    3513
# ...

# %% [markdown]
# # 4.Total cases Vs death ratio

# %%
df1.plot.bar( title="Total cases Vs Deths",x="State/UTs",orientation="vertical",figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'Total cases Vs Deths'}, xlabel='State/UTs'>

# %% [markdown]
# # 5.State wise deth percentage

# %%
df1=pd.DataFrame(df,columns=[ "State/UTs", "Death Ratio (%)"])

# %%
df1.plot.bar( title="State wise Deaths %",x="State/UTs",figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'State wise Deaths %'}, xlabel='State/UTs'>

# %% [markdown]
# # 6. Recovery rate

# %%
df2=pd.DataFrame(df,columns=[ "State/UTs","Discharge Ratio (%)"])

# %%
sns.pairplot(df2)

# %%
df2.plot.bar( title="State wise revovery %",x="State/UTs",figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'State wise revovery %'}, xlabel='State/UTs'>

# %% [markdown]
# # 7. Total surviver of Covid

# %%
df2=pd.DataFrame(df,columns=[ "State/UTs","Discharge Ratio (%)","Death Ratio (%)"])

# %%
df2.plot.bar( title="State wise revovery %",x="State/UTs",figsize=(20,10))
# Out:
# <AxesSubplot:title={'center':'State wise revovery %'}, xlabel='State/UTs'>

# %%
sns.pairplot(df1)

# %% [markdown]
# # 8 . Data overview

# %%
sns.pairplot(df)
